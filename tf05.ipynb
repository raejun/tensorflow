# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
my_data = []
for i in range(1000):
    x = np.random.normal(0, 1)
    y = 0.1 * x + np.random.normal(0, 0.05)
    my_data.append([x,y])
# my_data[:5]
x_data = [ v[0] for v in my_data ]
y_data = [ v[1] for v in my_data ]
plt.plot(x_data, y_data, 'ro')
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1], -1, 1))
b = tf.Variable(tf.zeros([1]))  ## b=0
hypothesis = W * x_data + b

cost = tf.reduce_mean(tf.square(hypothesis - y_data))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.2)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(10):
    print('step=', step, 'W=', sess.run(W), 'cost=', sess.run(cost))
    sess.run(train)
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    plt.show()

sess.close()
# Out:
# step= 0 W= [-0.76522684] cost= 0.7266029
# step= 1 W= [-0.4299516] cost= 0.27312884
# step= 2 W= [-0.22507669] cost= 0.10400015
# step= 3 W= [-0.09974554] cost= 0.0406404
# step= 4 W= [-0.02299131] cost= 0.016802866
# step= 5 W= [0.02406401] cost= 0.007798162
# step= 6 W= [0.05294198] cost= 0.004383587
# step= 7 W= [0.07068244] cost= 0.0030841413
# step= 8 W= [0.08159158] cost= 0.002587981
# step= 9 W= [0.08830635] cost= 0.0023979526
